# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import hdf5storage

import skimage
from skimage import data

# %%
from skimage import io

barn1 = []
for i in range(9):
    barn.append(io.imread("../datasets/scenes2001/barn1/im" + str(i) + ".ppm"))
# Out:
# c:\users\danyl\appdata\local\programs\python\python36\lib\site-packages\skimage\external\tifffile\tifffile.py:305: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "

# %%
plt.imshow(barn1[0])
