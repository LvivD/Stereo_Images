# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import hdf5storage

import skimage
from skimage import data

# %%
from skimage import io

barn1 = []
for i in range(9):
    barn1.append(io.imread("../datasets/scenes2001/barn1/im" + str(i) + ".ppm"))

# %%
plt.imshow(barn1[0])

# %%
plt.imshow(barn1[1])

# %%
plt.imshow(barn1[0] - barn1[1])
